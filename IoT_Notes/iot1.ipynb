# %% [markdown]
# ## iot codeblocks and notes
#
# 1.Initial iot notebook
#
# 2.Using requests curl and python
#
# ### Usage:
#
# 1.Using requests to retrieve data from API

# %%
import requests
import json

# %%
url = "https://mwshovel.pythonanywhere.com/dirt/beaches/Lac-Léman/?format=json"
beachData = requests.get(url).json()

# %%
beachData
# Out:
# [{'location': 'Anarchy-Beach',
#   'latitude': '46.44721600',
#   'longitude': '6.85961200',
#   'city': 'La-Tour-de-Peilz',
#   'post': '1814',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Arabie',
#   'latitude': '46.46209900',
#   'longitude': '6.83497200',
#   'city': 'Vevey',
#   'post': '1800',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Bain-des-Dames',
#   'latitude': '46.45050680',
#   'longitude': '6.85809180',
#   'city': 'La-Tour-de-Peilz',
#   'post': '1814',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Baye-de-Clarens',
#   'latitude': '46.43978700',
#   'longitude': '6.88890300',
#   'city': 'Montreux',
#   'post': '1815',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
# ...

# %%
url = "https://mwshovel.pythonanywhere.com/dirt/beaches/Lac-Léman/"
beachData = requests.get(url)

# %%
beachData
# Out:
# <Response [200]>

# %%
beachData
# Out:
# [{'location': 'Anarchy-Beach',
#   'latitude': '46.44721600',
#   'longitude': '6.85961200',
#   'city': 'La-Tour-de-Peilz',
#   'post': '1814',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Arabie',
#   'latitude': '46.46209900',
#   'longitude': '6.83497200',
#   'city': 'Vevey',
#   'post': '1800',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Bain-des-Dames',
#   'latitude': '46.45050680',
#   'longitude': '6.85809180',
#   'city': 'La-Tour-de-Peilz',
#   'post': '1814',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
#  {'location': 'Baye-de-Clarens',
#   'latitude': '46.43978700',
#   'longitude': '6.88890300',
#   'city': 'Montreux',
#   'post': '1815',
#   'water': 'l',
#   'water_name': 'Lac-Léman',
#   'project_id': 'MCBP',
#   'owner': 'mwshovel'},
# ...
